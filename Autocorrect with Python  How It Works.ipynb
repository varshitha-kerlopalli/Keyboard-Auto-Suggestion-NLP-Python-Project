# %%
import pandas as pd
import numpy as np
import textdistance
import re
from collections import Counter

# %% [markdown]
# # File Opening And Cleaning (change formate to utf-8)

# %%
# %pip install pandas numpy textdistance re
# Out:
# Requirement already satisfied: pandas in c:\users\rithi\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\rithi\appdata\local\programs\python\python312\lib\site-packages (1.26.2)
# Requirement already satisfied: textdistance in c:\users\rithi\appdata\local\programs\python\python312\lib\site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for re

# %%
word = []

with open('autocorrect book.txt', 'r', encoding='utf-8') as f:
    data = f.read()
    data = data.lower()
    words = re.findall(r'\w+', data)
    words += words

print(words[0:10])
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'moby', 'dick', 'or', 'the', 'whale']

# %% [markdown]
# # make vocabulary

# %%
len(words)
# Out:
# 445340

# %%
V = set(words)
V
# Out:
# {'john',
#  'persuasions',
#  'excepting',
#  'anticipated',
#  'monotonously',
#  'underground',
#  'latently',
#  'princely',
#  'dogged',
#  'glazier',
#  'angular',
#  'faintest',
#  'advised',
#  'hunts',
#  'royal',
#  'raphael',
#  'modern',
#  'absorbed',
#  'mean',
#  'arid',
#  '19',
#  'lane',
#  'feature',
#  'everythings',
#  'leather',
#  'sirs',
#  'achieved',
#  'twisting',
#  'staggeringly',
#  'picturesqueness',
#  'blisters',
#  'ishmael',
#  'unaccountable',
#  'fetor',
#  'animated',
#  'digestion',
#  'emptied',
#  'feeling',
#  'unwelcome',
#  'dinnerless',
#  'gleamings',
#  'attested',
#  'mouts',
#  'asylum',
#  'underwent',
#  'crowd',
#  'machines',
#  'sticking',
#  'endeavors',
#  'chronically',
#  'frost',
#  'disagreeable',
#  'preciousness',
#  'potters',
#  'sank',
#  'affixed',
#  'prompts',
#  'tracery',
#  'tempest',
#  'peltry',
#  'shafts',
#  'gravely',
#  'surtout',
#  'gashed',
#  'torrents',
#  'kennel',
#  'strictly',
#  '_long',
#  'steps',
#  'rides',
#  'vintage',
#  'transferred',
#  'immovable',
#  'japanese',
#  'bartered',
#  'midnight',
#  'bound',
#  'b',
#  'damaged',
#  'across',
#  'shoving',
#  'repels',
#  'beginning',
#  'wrapping',
#  'semicircle',
#  'allay',
#  '1778',
#  'blisteringly',
#  'stripping',
#  'astronomers',
#  'pained',
#  'plaything',
#  'rumbling',
#  'bernard',
#  '_sneezes_',
#  'gayhead',
#  'warmth',
#  'betake',
#  'teaches',
#  'citadel',
#  'pods',
#  'effeminacy',
#  'involving',
#  'animal_',
#  'waxed',
#  'peculiar',
#  'midmost',
#  'spluttering',
#  'joosy',
#  'professor',
#  'molesting',
#  '_multum',
#  'bosky',
#  'hintings',
#  'calmly',
#  'hare',
#  'thro',
#  'accompaniments',
#  'stubbornness',
#  'misanthrope',
#  'privation',
#  'shiningly',
#  'appeal',
#  'mate',
#  'ignominy',
#  'buffalo',
#  'cozening',
#  'vehicle',
#  'semicircular',
#  'noblemen',
#  'sufficiently',
#  'puncheons',
#  'dented',
#  'closed',
#  'echoes',
#  'unsmoothable',
#  'skip',
#  'o',
#  'maim',
#  'maxim',
#  'anacharsis',
#  'afflictions',
#  'embarking',
#  'allies',
#  'foremost',
#  'faction',
#  'fragrance',
#  'dragons',
#  'affecting',
#  'dispensed',
#  'verily',
#  'delight',
#  'spangled',
#  'dismember',
#  'friction',
#  'sherry',
#  'accelerated',
#  'circumstance',
#  'healed',
#  'tolland',
#  'destroyed',
#  'wonst',
#  'lege',
#  'idea',
#  'inarticulate',
#  'flogged',
#  'performance',
#  'vintages',
#  'begins',
#  'frequency',
#  'stilly',
#  'creaking',
#  'tangles',
#  'clearly',
#  'orphan',
#  'surging',
#  'bunting',
#  'expect',
#  'beard',
#  'delicately',
#  'simultaneousness',
#  'sorrow',
#  'shored',
#  'soliloquizer',
#  'abide',
#  'catcher',
#  'needle',
#  'plumage',
#  'removing',
#  'profuse',
#  'impotence',
#  'centralization',
#  'tapped',
#  'wrestlings',
#  'dauntlessness',
#  'tost',
#  'emblazonings',
#  'wonderfulness',
#  'wills',
#  'tags',
#  'contemptibly',
#  'obeyest',
#  'dinting',
#  'cask',
#  'myself',
#  'helm',
#  'seasoned',
#  'ground',
#  'solemn',
#  'bitts',
#  'ophites',
#  'social',
#  'observant',
#  'griefs',
#  'joking',
#  'adolescence',
#  'amen',
#  'phrensy',
#  'fasces',
#  'wine',
#  'relied',
#  'covering',
#  'daunted',
#  'keeping',
#  'cocked',
#  'damp',
#  'rather',
#  'cows',
#  '_dost_',
#  'mouth',
#  'toying',
#  '86',
#  'enderbys',
#  'note',
#  'krusenstern',
#  'phrensied',
#  'revels',
#  'lethargy',
#  'wire',
#  'work',
#  'stylites',
#  'divide',
#  'resorting',
#  'pilgrims',
#  'pleasure',
#  'cannibalistically',
#  'forget',
#  'consciousness',
#  'pole',
#  'chartering',
#  'swain',
#  'unobstructed',
#  'wilt',
#  'brained',
#  'require',
#  'wheelbarrow',
#  'archangelic',
#  'rumors',
#  'catched',
#  'kicks',
#  'mildly',
#  'cutlass',
#  'endangered',
#  'analogies',
#  'systematized',
#  'cent',
#  'intense',
#  'chin',
#  'yarman',
#  'eastwards',
#  'thimbleful',
#  'casked',
#  'laughable',
#  'unmomentous',
#  'interrupted',
#  'moccasined',
#  'bravest',
#  'bridge',
#  'inflicted',
#  'mindedness',
#  'hatchway',
#  'weld',
#  'omens',
#  'servile',
#  'amphitheatrical',
#  'seconds',
#  'swash',
#  'bluntly',
#  'bermudas',
#  'speech',
#  'romish',
#  'sayest',
#  'eloquently',
#  'regarding',
#  'lobtailing',
#  'curve',
#  'corlears',
#  'limber',
#  'heed',
#  'scolds',
#  'internationally',
#  'waxes',
#  'asa',
#  'ninetieth',
#  'unthinkingly',
#  'crept',
#  'columbus',
#  'impregnably',
#  'damped',
#  'gap',
#  'gentleman',
#  '_spanish_',
#  'ruggedest',
#  '_november_',
#  'hilarious',
#  'calomel',
#  'puzzling',
#  'foundations',
#  'flies',
#  'flanks',
#  'yellowish',
#  'clean',
#  'quivering',
#  'dwells',
#  'dan',
#  'athletic',
#  'inlaying',
#  'closer',
#  'vapory',
#  'socket',
#  'strove',
#  'arrested',
#  'predominating',
#  'fine',
#  'undoubtedly',
#  'legged',
#  'marvels',
#  'intermeddling',
#  '_i_',
#  'prick',
#  '70',
#  'zogranda',
#  'half',
#  'considerably',
#  'floats',
#  'strikes',
#  'bulge',
#  '108',
#  'fobbing',
#  'necessarily',
#  'motion',
#  'disengaged',
#  'section',
#  'mansion',
#  'wring',
#  'hastier',
#  'kelson',
#  'creed',
#  'thrust',
#  'shudder',
#  'viewing',
#  'withdraws',
#  'muscular',
#  'harmed',
#  '_breach_',
#  'swims',
#  'ice',
#  'volley',
#  'chivalric',
#  'marsh',
#  'quilted',
#  'plains',
#  'provincials',
#  'partial',
#  'squeezing',
#  'guernseyman',
#  'some',
#  'utf',
#  'avatar',
#  'folio',
#  'surrenderest',
#  'persuading',
#  'actuated',
#  'magical',
#  'respects',
#  'context',
#  'invent',
#  'received',
#  'echo',
#  'befogged',
#  'ungovernable',
#  'angry',
#  'faces',
#  'supper',
#  'department',
#  'disguisement',
#  'meshach',
#  'cenotaphs',
#  'mangles',
#  'garters',
#  'as',
#  'amid',
#  'stalking',
#  'socially',
#  'hish',
#  'endearments',
#  'brush',
#  'lonesomeness',
#  'scabbards',
#  'curios',
#  'casual',
#  'give',
#  'villany',
#  'innocent',
#  'stolidly',
#  'herons',
#  'bags',
#  'phraseology',
#  'domineerings',
#  'leads',
#  'german',
#  'coalescing',
#  'saith',
#  'tangle',
#  'founder',
#  'copied',
#  'rogers',
#  'worn',
#  'wisdom',
#  'rude',
#  'quito',
#  'upheld',
#  'upbubble',
#  'enterprises',
#  'forbearing',
#  'mastery',
#  'pulls',
#  'murderer',
#  'mingling',
#  'satisfied',
#  'scanning',
#  'prodromus',
#  'vaguely',
#  'chastisements',
#  'skilfully',
#  'surroundingly',
#  '6',
#  'tilbury',
#  'aggregated',
#  'surpasses',
#  'exclude',
#  'depresses',
#  'strenuous',
#  'stop',
#  'sincerity',
#  'child',
#  'parenthesize',
#  'drench',
#  'idolator',
#  'bath',
#  'sarmon',
#  'lapse',
#  'durer',
#  'expectant',
#  'denominate',
#  'auto',
#  '_cooper',
#  'unmanufactured',
#  'beauty',
#  'continued',
#  'flow',
#  'belubed',
#  'philosophical',
#  'epicures',
#  'wipe',
#  'thinking',
#  'vales',
#  'caw',
#  'cruet',
#  'medals',
#  'proper',
#  'solar',
#  'expressly',
#  'shouts',
#  'melted',
#  'resolved',
#  'either',
#  'morally',
#  'arpens',
#  'strings',
#  'er',
#  'missouri',
#  'feared',
#  'drained',
#  'pail',
#  'sleepe',
#  'mealtimes',
#  'julys',
#  'secured',
#  'motionlessly',
#  'cargo',
#  'disparagement',
#  'loads',
#  'swarming',
#  'clifford',
#  'claret',
#  'herculaneum',
#  'apple',
#  'pecked',
#  'blindest',
#  'nautilus',
#  'owest',
#  'hindmost',
#  'whoop',
#  'festival',
#  'blinded',
#  'brooding',
#  'course',
#  'involve',
#  'plazza',
#  'celestial',
#  'streams',
#  'unextinguished',
#  'exhaled',
#  'publisher',
#  'hospitality',
#  'brazil',
#  'steel',
#  'million',
#  'durable',
#  'shallow',
#  'brother',
#  'anything',
#  'hearty',
#  'establish',
#  'action',
#  'structures',
#  'brushed',
#  'plans',
#  'twins',
#  'influential',
#  'teats',
#  'box',
#  'junior',
#  '1775',
#  'rips',
#  'shyness',
#  'haters',
#  'controls',
#  'neighborhood',
#  'exception',
#  'warfare',
#  'affect',
#  'true',
#  'incomputable',
#  'pitchpoling',
#  'touched',
#  'steered',
#  'issuing',
#  'drags',
#  'though',
#  'colossus',
#  'chewing',
#  'overmuch',
#  'unsurrendered',
#  'hinges',
#  'mealy',
#  'conquest',
#  'vengeful',
#  'upbraiding',
#  'oversight',
#  'committing',
#  'deified',
#  'stuffed',
#  'concluding',
#  'created',
#  'gregarious',
#  'quaffed',
#  'buck',
#  'briefly',
#  'relations',
#  'blast',
#  'dies',
#  'willow',
#  'reeling',
#  'ween',
#  'suds',
#  'officio_',
#  'devils',
#  'devious',
#  'upliftings',
#  'pierced',
#  'inelegant',
#  'intricacies',
#  'waste',
#  'usages',
#  '144',
#  'therefore',
#  'cooler',
#  'cavern',
#  'seasoning',
#  'tablet',
#  'prophets',
#  'contraband',
#  'paris',
#  'annus',
#  'accessed',
#  'coincident',
#  'sam',
#  'user',
#  'daily',
#  's_',
#  'striven',
#  'steal',
#  'notorious',
#  'wast',
#  'tinkling',
#  'intending',
#  'abundantly',
#  'fury',
#  'tube',
#  'bleak',
#  'classical',
#  'shelf',
#  'careening',
#  'irradiate',
#  'ship',
#  'hatband',
#  'tips',
#  'rover',
#  'yellow',
#  'hand',
#  'patron',
#  'six',
#  'previous',
#  'boisterous',
#  'darkens',
#  'trance',
#  'support',
#  'excursion',
#  'faltering',
#  'meadows',
#  'steep',
#  'doomed',
#  'starlight',
#  'indebtedness',
#  'reddenest',
#  'scenery',
#  'fleetness',
#  'she',
#  'parade',
#  'usurper',
#  '2nd',
#  'accommodate',
#  'shem',
#  'ruinous',
#  'bashaw',
#  'pallidness',
#  'irs',
#  'wields',
#  'reflected',
#  'scar',
#  'remain',
#  'architecture',
#  'villanous',
#  'too',
#  'ledge',
#  'tobacco',
#  'fleeting',
#  '_be_',
#  'whets',
#  '_lays_',
#  'talking',
#  'loomed',
#  'counted',
#  'mat_',
#  'feminam',
#  'contrivances',
#  'bombay',
#  'grunted',
#  'maternal',
#  'monkey',
#  '12',
#  'pulled',
#  'spirits',
#  'hearse',
#  'enfeebled',
#  'seemly',
#  'chained',
#  'dotted',
#  'seating',
#  '_splice_',
#  'development',
#  'whalesmen',
#  'towering',
#  'publicly',
#  'rarmai',
#  'sending',
#  'extremest',
#  'nooks',
#  'uneasy',
#  'prayer',
#  'bowled',
#  'dining',
#  'snapped',
#  'collegians',
#  'dreaming',
#  'meant',
#  'cetology',
#  'caution',
#  '67',
#  'since',
#  'ribbed',
#  'bite',
#  'shadowed',
#  'mongrel',
#  'subjected',
#  'dislocated',
#  'unsignifying',
#  'futures',
#  'wearied',
#  'victory',
#  'stubbornly',
#  'vigorous',
#  'part',
#  'barbecue',
#  'dardanelles',
#  'incorrigible',
#  'fundraising',
#  'hurler',
#  'earned',
#  'buoyant',
#  'demi',
#  'idiom',
#  'aquarius',
#  'waked',
#  'go_',
#  'breaths',
#  'seeing',
#  'wish',
#  'pehee',
#  'column',
#  'conjoined',
#  'hindoo',
#  'elevations',
#  'topsail',
#  'selecting',
#  'brack',
#  'enlivened',
#  'dusk',
#  'whole',
#  'unstreaked',
#  'aboriginalness',
#  'immense',
#  'absent',
#  'quadrant',
#  'reasonable',
#  'positive',
#  'races',
#  'roly',
#  'warmly',
#  'moses',
#  'pleasantness',
#  'glory',
#  'folds',
#  'mode',
#  'cherubim',
#  'tune',
#  'barques',
#  'mayst',
#  'rampart',
#  'cowhide',
#  'persia',
#  'ray',
#  'imperceptible',
#  'dention',
#  'disbands',
#  'pictures',
#  'nomine',
#  'greatly',
#  'truthful',
#  'paces',
#  'spool',
#  'unsafe',
#  'boarding',
#  'hart',
#  'yawingly',
#  'sensitive',
#  'whereupon',
#  'nick',
#  'abashed',
#  'insomuch',
#  'landsmen',
#  'breastband',
#  'boats',
#  'mapped',
#  'saddest',
#  'deserts',
#  'sod',
#  'unparticipated',
#  'cock',
#  'intricacy',
#  'dyspepsia',
#  'hush',
#  'wreck',
#  'concreted',
#  'throttling',
#  'a',
#  'carved',
#  'rum',
#  'lover',
#  'indications',
#  'parts',
#  'skrimshandering',
#  'flailing',
#  'burtons',
#  'smiling',
#  'straightway',
#  'deaf',
#  'centaurs',
#  'proceedings',
#  'jaundice',
#  'altogether',
#  'keeps',
#  'magician',
#  'warmed',
#  'imparted',
#  'fairbanks',
#  'straps',
#  'expectantly',
#  'mail',
#  'condensed',
#  'precipice',
#  'insist',
#  'reservoir',
#  'woodlands',
#  'horizontal',
#  'furred',
#  'graded',
#  'invariably',
#  'imprecations',
#  'ramming',
#  'sometimes',
#  'influenced',
#  'erring',
#  'reverse',
#  'likened',
#  'flaming',
#  'mists',
#  'roman',
#  'wrangling',
#  'rot',
#  'jew',
#  'forthwith',
#  'solicitation',
#  '_hamlet_',
#  'breakfasting',
#  'victories',
#  'borders',
#  'pledge',
#  'trappers',
#  'immutable',
#  'rolling',
#  'adventurous',
#  'lash',
#  'vagabond',
#  'tantalizing',
#  'causes',
#  'feegees',
#  'willingness',
#  'convent',
#  'corrupt',
#  'arises',
#  'aroostook',
#  'fidelity',
#  'whelmed',
#  'strides',
#  'reputed',
#  'gleig',
#  'dunder',
#  'induce',
#  'pertaining',
#  'adopted',
#  'convince',
#  'criminal',
#  'investigation',
#  'teetering',
#  'reaches',
#  'ham',
#  'provinces',
#  'stalls',
#  'testified',
#  'glimmering',
#  'fins',
#  'shoulder',
#  'net',
#  'profitably',
#  'premeditated',
#  'toilet',
#  'reg',
#  'crumpled',
#  'spilled',
#  'stealthily',
#  'industrious',
#  'joyfully',
#  'remoter',
#  'classify',
#  'multiplicity',
#  'regained',
#  'refreshing',
#  '801',
#  'spherical',
#  'puissant',
#  '_miriam',
#  'humbly',
#  'goose',
#  'horribly',
#  'jointed',
#  'deception',
#  'violence',
#  'mole',
#  'dark',
#  'shakes',
#  'heeding',
#  'brick',
#  'braided',
#  'resistance',
#  'feet_',
#  'don',
#  'shabby',
#  'wives',
#  'gras',
#  'aroma',
#  'stones',
#  'glitters',
#  'inference',
#  'attract',
#  'laugh',
#  'unassured',
#  'beam',
#  'christianity',
#  'securities',
#  'proportions',
#  'caved',
#  'midwinter',
#  'getting',
#  'considerations',
#  'bleeds',
#  'contents',
#  'observe',
#  'lengthwise',
#  'dong',
#  'wreath',
#  '_dancing_',
#  'consider',
#  'hav',
#  'ian_',
#  'frequented',
#  'euclidean',
#  'derision',
#  'specially',
#  'plumping',
#  'aboriginal',
#  'axe',
#  'oly',
#  'meanwhile',
#  'ninety',
#  'giving',
#  'diabolically',
#  '_latin_',
#  'moreover',
#  'advertised',
#  'jackal',
#  'barbaric',
#  'unneeded',
#  'spademan',
#  'book',
#  'slice',
#  'language',
#  'fés',
#  'depict',
#  'glue',
#  'undiscriminating',
#  'dawned',
#  'miniatures',
#  'distrusted',
#  'anybody',
#  '40',
#  'decanter',
#  'exiled',
#  'jordan',
#  'steeds',
#  'unwinding',
#  'considering',
#  'coward',
#  'gaffs',
#  'mustering',
#  'avenger',
#  'claws',
#  'obed',
#  ...}

# %%
len(V)
# Out:
# 17647

# %% [markdown]
# # build the frequency of those words

# %%
words_freq_dict = {}
words_freq_dict = Counter(words)

# %%
words_freq_dict.most_common()[0:10]
# Out:
# [('the', 29406),
#  ('of', 13484),
#  ('and', 13034),
#  ('a', 9598),
#  ('to', 9414),
#  ('in', 8480),
#  ('that', 6162),
#  ('it', 5068),
#  ('his', 5060),
#  ('i', 4240)]

# %% [markdown]
# # Relative Frequency of words

# %%
Total = sum(words_freq_dict.values())
probs = {}

for k in words_freq_dict.keys():
    probs[k] = words_freq_dict[k] / Total

# %%
probs
# Out:
# {'the': 0.06603044864597836,
#  'project': 0.0004086765168186105,
#  'gutenberg': 0.00042214936902142185,
#  'ebook': 4.490950734270445e-05,
#  'of': 0.03027798985045134,
#  'moby': 0.00040418556608434004,
#  'dick': 0.00040418556608434004,
#  'or': 0.0035792877352135446,
#  'whale': 0.005523869403152647,
#  'by': 0.005487941797278484,
#  'herman': 1.796380293708178e-05,
#  'melville': 1.796380293708178e-05,
#  'this': 0.0064624781066151705,
#  'is': 0.00786365473570755,
#  'for': 0.007383123007140612,
#  'use': 0.0002200565859792518,
#  'anyone': 2.694570440562267e-05,
#  'anywhere': 7.185521174832712e-05,
#  'at': 0.005995419230251044,
#  'no': 0.0026676247361566443,
#  'cost': 1.796380293708178e-05,
#  'and': 0.029267525935240492,
#  'with': 0.007944491848924417,
#  'almost': 0.0008847172946512777,
#  'restrictions': 8.98190146854089e-06,
#  'whatsoever': 3.1436655139893116e-05,
#  'you': 0.0043023308034310865,
#  'may': 0.0011451924372389635,
#  'copy': 8.532806395113846e-05,
#  'it': 0.011380069160641307,
#  'give': 0.00040418556608434004,
#  'away': 0.0008353168365743028,
#  're': 8.083711321686801e-05,
#  'under': 0.0005658597925180761,
#  'terms': 0.0001482013742309247,
#  'license': 8.083711321686801e-05,
#  'included': 6.287331027978623e-05,
#  'online': 1.796380293708178e-05,
#  'www': 2.694570440562267e-05,
#  'org': 5.838235954551579e-05,
#  'title': 3.592760587416356e-05,
#  'author': 4.0418556608434004e-05,
#  'release': 4.490950734270445e-06,
#  'date': 1.796380293708178e-05,
#  'december': 2.2454753671352224e-05,
#  '25': 1.796380293708178e-05,
#  '2008': 4.490950734270445e-06,
#  '2701': 1.796380293708178e-05,
#  'last': 0.0012484843041271837,
#  'updated': 8.98190146854089e-06,
#  '3': 7.185521174832712e-05,
#  '2017': 4.490950734270445e-06,
#  'language': 3.1436655139893116e-05,
#  'english': 0.0002200565859792518,
#  'character': 6.736426101405667e-05,
#  'set': 0.00038173081241298784,
#  'encoding': 4.490950734270445e-06,
#  'utf': 4.490950734270445e-06,
#  '8': 3.1436655139893116e-05,
#  'start': 0.00016616517716800647,
#  'produced': 4.0418556608434004e-05,
#  'daniel': 1.796380293708178e-05,
#  'lazarus': 3.1436655139893116e-05,
#  'jonesey': 8.98190146854089e-06,
#  'david': 8.98190146854089e-06,
#  'widger': 8.98190146854089e-06,
#  'contents': 3.592760587416356e-05,
#  'etymology': 8.98190146854089e-06,
#  'extracts': 3.1436655139893116e-05,
#  'supplied': 5.838235954551579e-05,
#  'a': 0.021552072573763865,
#  'sub': 4.0418556608434004e-05,
#  'librarian': 8.98190146854089e-06,
#  'chapter': 0.0013832128261552972,
#  '1': 0.0002200565859792518,
#  'loomings': 8.98190146854089e-06,
#  '2': 3.1436655139893116e-05,
#  'carpet': 4.0418556608434004e-05,
#  'bag': 0.00010329186688822024,
#  'spouter': 3.592760587416356e-05,
#  'inn': 7.634616248259757e-05,
#  '4': 4.0418556608434004e-05,
#  'counterpane': 3.592760587416356e-05,
#  '5': 3.1436655139893116e-05,
#  'breakfast': 6.736426101405667e-05,
#  '6': 1.796380293708178e-05,
#  'street': 6.287331027978623e-05,
#  '7': 3.1436655139893116e-05,
#  'chapel': 4.940045807697489e-05,
#  'pulpit': 7.634616248259757e-05,
#  '9': 2.2454753671352224e-05,
#  'sermon': 2.2454753671352224e-05,
#  '10': 2.2454753671352224e-05,
#  'bosom': 4.0418556608434004e-05,
#  'friend': 0.00012125566982530201,
#  '11': 8.98190146854089e-06,
#  'nightgown': 8.98190146854089e-06,
#  '12': 8.98190146854089e-06,
#  'biographical': 8.98190146854089e-06,
#  '13': 1.796380293708178e-05,
#  'wheelbarrow': 1.796380293708178e-05,
#  '14': 8.98190146854089e-06,
#  'nantucket': 0.00042214936902142185,
#  '15': 8.98190146854089e-06,
#  'chowder': 4.490950734270445e-05,
#  '16': 8.98190146854089e-06,
#  'ship': 0.002330803431086361,
#  '17': 8.98190146854089e-06,
#  'ramadan': 5.389140881124534e-05,
#  '18': 8.98190146854089e-06,
#  'his': 0.011362105357704226,
#  'mark': 0.0002514932411191449,
#  '19': 8.98190146854089e-06,
#  'prophet': 7.634616248259757e-05,
#  '20': 2.2454753671352224e-05,
#  'all': 0.006934027933713567,
#  'astir': 1.796380293708178e-05,
#  '21': 8.98190146854089e-06,
#  'going': 0.00040418556608434004,
#  'aboard': 9.880091615394978e-05,
#  '22': 8.98190146854089e-06,
#  'merry': 6.287331027978623e-05,
#  'christmas': 2.694570440562267e-05,
#  '23': 8.98190146854089e-06,
#  'lee': 9.430996541967935e-05,
#  'shore': 0.00011676471909103158,
#  '24': 8.98190146854089e-06,
#  'advocate': 1.796380293708178e-05,
#  'postscript': 8.98190146854089e-06,
#  '26': 8.98190146854089e-06,
#  'knights': 2.694570440562267e-05,
#  'squires': 1.796380293708178e-05,
#  '27': 8.98190146854089e-06,
#  '28': 8.98190146854089e-06,
#  'ahab': 0.002299366775946468,
#  '29': 8.98190146854089e-06,
#  'enter': 4.940045807697489e-05,
#  'to': 0.021138905106210984,
#  'him': 0.004782862531998024,
#  'stubb': 0.0011631562401760453,
#  '30': 1.796380293708178e-05,
#  'pipe': 0.0001886199308393587,
#  '31': 8.98190146854089e-06,
#  'queen': 8.083711321686801e-05,
#  'mab': 8.98190146854089e-06,
#  '32': 8.98190146854089e-06,
#  'cetology': 4.940045807697489e-05,
#  '33': 8.98190146854089e-06,
#  'specksnyder': 1.796380293708178e-05,
#  '34': 8.98190146854089e-06,
#  'cabin': 0.00039071271388152874,
#  'table': 0.00017065612790227692,
#  '35': 8.98190146854089e-06,
#  'mast': 0.0005838235954551579,
#  'head': 0.001562850855526115,
#  '36': 8.98190146854089e-06,
#  'quarter': 0.00021556563524498137,
#  'deck': 0.0008936991961198186,
#  '37': 8.98190146854089e-06,
#  'sunset': 4.490950734270445e-05,
#  '38': 8.98190146854089e-06,
#  'dusk': 1.3472852202811336e-05,
#  '39': 8.98190146854089e-06,
#  'first': 0.0010733372254906363,
#  'night': 0.0006826245116091077,
#  'watch': 0.00027394799479049713,
#  '40': 1.3472852202811336e-05,
#  'midnight': 0.00013472852202811334,
#  'forecastle': 0.00017065612790227692,
#  '41': 8.98190146854089e-06,
#  '42': 8.98190146854089e-06,
#  'whiteness': 0.00012574662055957246,
#  '43': 8.98190146854089e-06,
#  'hark': 7.634616248259757e-05,
#  '44': 8.98190146854089e-06,
#  'chart': 3.592760587416356e-05,
#  '45': 1.3472852202811336e-05,
#  'affidavit': 1.3472852202811336e-05,
#  '46': 8.98190146854089e-06,
#  'surmises': 1.796380293708178e-05,
#  '47': 8.98190146854089e-06,
#  'mat': 5.838235954551579e-05,
#  'maker': 2.2454753671352224e-05,
#  '48': 8.98190146854089e-06,
#  'lowering': 8.532806395113846e-05,
#  '49': 8.98190146854089e-06,
#  'hyena': 1.796380293708178e-05,
#  '50': 1.3472852202811336e-05,
#  's': 0.00817353033637221,
#  'boat': 0.0014999775452463286,
#  'crew': 0.0006332240535321328,
#  'fedallah': 0.00012574662055957246,
#  '51': 8.98190146854089e-06,
#  'spirit': 8.532806395113846e-05,
#  'spout': 0.00027394799479049713,
#  '52': 8.98190146854089e-06,
#  'albatross': 4.490950734270445e-05,
#  '53': 8.98190146854089e-06,
#  'gam': 2.694570440562267e-05,
#  '54': 8.98190146854089e-06,
#  'town': 0.00016167422643373602,
#  'ho': 0.00014371042349665424,
#  'story': 0.0002290384874477927,
#  '55': 8.98190146854089e-06,
#  'monstrous': 5.389140881124534e-05,
#  'pictures': 8.532806395113846e-05,
#  'whales': 0.0012170476489872905,
#  '56': 8.98190146854089e-06,
#  'less': 0.00024251133965060402,
#  'erroneous': 8.98190146854089e-06,
#  'true': 0.00039520366461579914,
#  'whaling': 0.0005928054969236988,
#  'scenes': 5.389140881124534e-05,
#  '57': 8.98190146854089e-06,
#  'in': 0.019041631113306687,
#  'paint': 3.1436655139893116e-05,
#  'teeth': 0.00022454753671352225,
#  'wood': 0.00016616517716800647,
#  'sheet': 4.0418556608434004e-05,
#  'iron': 0.00039520366461579914,
#  'stone': 8.98190146854089e-05,
#  'mountains': 6.287331027978623e-05,
#  'stars': 6.287331027978623e-05,
#  '58': 8.98190146854089e-06,
#  'brit': 4.0418556608434004e-05,
#  '59': 8.98190146854089e-06,
#  'squid': 3.592760587416356e-05,
#  '60': 1.796380293708178e-05,
#  'line': 0.0007185521174832712,
#  '61': 8.98190146854089e-06,
#  'kills': 1.3472852202811336e-05,
#  '62': 8.98190146854089e-06,
#  'dart': 0.00011676471909103158,
#  '63': 8.98190146854089e-06,
#  'crotch': 4.940045807697489e-05,
#  '64': 1.3472852202811336e-05,
#  'supper': 0.0001392194727623838,
#  '65': 8.98190146854089e-06,
#  'as': 0.00786814568644182,
#  'dish': 4.940045807697489e-05,
#  '66': 8.98190146854089e-06,
#  'shark': 0.0001392194727623838,
#  'massacre': 1.3472852202811336e-05,
#  '67': 8.98190146854089e-06,
#  'cutting': 0.00017065612790227692,
#  '68': 8.98190146854089e-06,
#  'blanket': 6.287331027978623e-05,
#  '69': 8.98190146854089e-06,
#  'funeral': 2.694570440562267e-05,
#  '70': 8.98190146854089e-06,
#  'sphynx': 1.3472852202811336e-05,
#  '71': 8.98190146854089e-06,
#  'jeroboam': 4.940045807697489e-05,
#  '72': 1.3472852202811336e-05,
#  'monkey': 7.634616248259757e-05,
#  'rope': 0.0002694570440562267,
#  '73': 8.98190146854089e-06,
#  'flask': 0.0004895136300354786,
#  'kill': 0.00015269232496519514,
#  'right': 0.000696097363811919,
#  'then': 0.0028292989625903803,
#  'have': 0.0034759958683253244,
#  'talk': 0.00011676471909103158,
#  'over': 0.0018412898010508824,
#  '74': 8.98190146854089e-06,
#  'sperm': 0.0010868100776934477,
#  'contrasted': 1.796380293708178e-05,
#  'view': 0.00022454753671352225,
#  '75': 8.98190146854089e-06,
#  '76': 8.98190146854089e-06,
#  'battering': 3.1436655139893116e-05,
#  'ram': 3.592760587416356e-05,
#  '77': 8.98190146854089e-06,
#  'great': 0.0013787218754210265,
#  'heidelburgh': 4.0418556608434004e-05,
#  'tun': 6.736426101405667e-05,
#  '78': 8.98190146854089e-06,
#  'cistern': 2.2454753671352224e-05,
#  'buckets': 2.694570440562267e-05,
#  '79': 8.98190146854089e-06,
#  'prairie': 5.838235954551579e-05,
#  '80': 8.98190146854089e-06,
#  'nut': 2.2454753671352224e-05,
#  '81': 8.98190146854089e-06,
#  'pequod': 0.0007948982799658688,
#  'meets': 6.287331027978623e-05,
#  'virgin': 5.389140881124534e-05,
#  '82': 8.98190146854089e-06,
#  'honor': 0.00011227376835676112,
#  'glory': 8.532806395113846e-05,
#  '83': 8.98190146854089e-06,
#  'jonah': 0.00038173081241298784,
#  'historically': 8.98190146854089e-06,
#  'regarded': 0.00011227376835676112,
#  '84': 8.98190146854089e-06,
#  'pitchpoling': 3.1436655139893116e-05,
#  '85': 8.98190146854089e-06,
#  'fountain': 4.490950734270445e-05,
#  '86': 8.98190146854089e-06,
#  'tail': 0.00036376700947590604,
#  '87': 8.98190146854089e-06,
#  'grand': 0.00024251133965060402,
#  'armada': 8.98190146854089e-06,
#  '88': 8.98190146854089e-06,
#  'schools': 4.0418556608434004e-05,
#  'schoolmasters': 1.3472852202811336e-05,
#  '89': 8.98190146854089e-06,
#  'fast': 0.0002874208469933085,
#  'fish': 0.0007589706740917052,
#  'loose': 0.00016616517716800647,
#  '90': 1.796380293708178e-05,
#  'heads': 0.00039071271388152874,
#  'tails': 3.592760587416356e-05,
#  '91': 8.98190146854089e-06,
#  'rose': 0.00015718327569946557,
#  'bud': 2.694570440562267e-05,
#  '92': 8.98190146854089e-06,
#  'ambergris': 6.287331027978623e-05,
#  '93': 8.98190146854089e-06,
#  'castaway': 2.2454753671352224e-05,
#  '94': 8.98190146854089e-06,
#  'squeeze': 4.490950734270445e-05,
#  'hand': 0.0009655544078681457,
#  '95': 8.98190146854089e-06,
#  'cassock': 1.3472852202811336e-05,
#  '96': 8.98190146854089e-06,
#  'try': 0.0002470022903848745,
#  'works': 0.0002874208469933085,
#  '97': 8.98190146854089e-06,
#  'lamp': 0.00013472852202811334,
#  '98': 8.98190146854089e-06,
#  'stowing': 1.3472852202811336e-05,
#  'down': 0.0017020703282884986,
#  'clearing': 2.694570440562267e-05,
#  'up': 0.0023622400862262543,
#  '99': 8.98190146854089e-06,
#  'doubloon': 9.430996541967935e-05,
#  '100': 1.796380293708178e-05,
#  'leg': 0.0004086765168186105,
#  'arm': 0.00040418556608434004,
#  '101': 8.98190146854089e-06,
#  'decanter': 1.3472852202811336e-05,
#  '102': 8.98190146854089e-06,
#  'bower': 1.796380293708178e-05,
#  'arsacides': 1.796380293708178e-05,
#  '103': 8.98190146854089e-06,
#  'measurement': 1.796380293708178e-05,
#  'skeleton': 0.00015718327569946557,
#  '104': 8.98190146854089e-06,
#  'fossil': 2.2454753671352224e-05,
#  '105': 8.98190146854089e-06,
#  'does': 0.0004401131719585036,
#  'magnitude': 0.00010329186688822024,
#  'diminish': 2.2454753671352224e-05,
#  'will': 0.0017918893429739076,
#  'he': 0.008514842592176764,
#  'perish': 2.2454753671352224e-05,
#  '106': 8.98190146854089e-06,
#  '107': 8.98190146854089e-06,
#  'carpenter': 0.00022454753671352225,
#  '108': 8.98190146854089e-06,
#  '109': 8.98190146854089e-06,
#  'starbuck': 0.0008936991961198186,
#  '110': 8.98190146854089e-06,
#  'queequeg': 0.0011362105357704225,
#  'coffin': 0.0002380203889163336,
#  '111': 8.98190146854089e-06,
#  'pacific': 0.00015718327569946557,
#  '112': 8.98190146854089e-06,
#  'blacksmith': 9.880091615394978e-05,
#  '113': 8.98190146854089e-06,
#  'forge': 5.838235954551579e-05,
#  '114': 8.98190146854089e-06,
#  'gilder': 8.98190146854089e-06,
#  '115': 8.98190146854089e-06,
#  'bachelor': 4.0418556608434004e-05,
#  '116': 8.98190146854089e-06,
#  'dying': 6.736426101405667e-05,
#  '117': 8.98190146854089e-06,
#  '118': 8.98190146854089e-06,
#  'quadrant': 4.0418556608434004e-05,
#  '119': 8.98190146854089e-06,
#  'candles': 4.490950734270445e-05,
#  '120': 8.98190146854089e-06,
#  'towards': 0.0005164593344411012,
#  'end': 0.00046256792562985585,
#  '121': 8.98190146854089e-06,
#  'bulwarks': 0.00017065612790227692,
#  '122': 8.98190146854089e-06,
#  'aloft': 0.00028292989625903803,
#  'thunder': 0.00014371042349665424,
#  'lightning': 0.00012574662055957246,
#  '123': 8.98190146854089e-06,
#  'musket': 4.0418556608434004e-05,
#  '124': 8.98190146854089e-06,
#  'needle': 5.389140881124534e-05,
#  '125': 8.98190146854089e-06,
#  'log': 0.00010329186688822024,
#  '126': 8.98190146854089e-06,
#  'life': 0.0007859163784973279,
#  'buoy': 6.287331027978623e-05,
#  '127': 8.98190146854089e-06,
#  '128': 8.98190146854089e-06,
#  'rachel': 3.1436655139893116e-05,
#  '129': 8.98190146854089e-06,
#  '130': 8.98190146854089e-06,
#  'hat': 0.00018412898010508824,
#  '131': 8.98190146854089e-06,
#  'delight': 8.532806395113846e-05,
#  '132': 8.98190146854089e-06,
#  'symphony': 8.98190146854089e-06,
#  '133': 8.98190146854089e-06,
#  'chase': 0.0002784389455247676,
#  'day': 0.0008038801814344097,
#  '134': 8.98190146854089e-06,
#  'second': 0.0002784389455247676,
#  '135': 8.98190146854089e-06,
#  'third': 0.00015269232496519514,
#  'epilogue': 8.98190146854089e-06,
#  'original': 0.00010329186688822024,
#  'transcriber': 4.490950734270445e-06,
#  'notes': 1.796380293708178e-05,
#  'text': 2.694570440562267e-05,
#  'combination': 8.98190146854089e-06,
#  'etexts': 4.490950734270445e-06,
#  'one': 0.004149638478465891,
#  'from': 0.004958009610634572,
#  'now': 0.00352988727713657,
#  'defunct': 8.98190146854089e-06,
#  'eris': 4.490950734270445e-06,
#  'virginia': 2.694570440562267e-05,
#  'tech': 8.98190146854089e-06,
#  'archives': 4.490950734270445e-06,
#  'proofreaders': 4.490950734270445e-06,
#  'version': 2.694570440562267e-05,
#  'are': 0.002775407553779135,
#  'indebted': 8.98190146854089e-06,
#  'university': 4.490950734270445e-06,
#  'adelaide': 4.490950734270445e-06,
#  'library': 1.3472852202811336e-05,
#  'preserving': 1.796380293708178e-05,
#  'resulting': 1.3472852202811336e-05,
#  'etext': 4.490950734270445e-06,
#  'was': 0.007392104908609152,
#  'compared': 4.0418556608434004e-05,
#  'public': 6.736426101405667e-05,
#  'domain': 4.0418556608434004e-05,
#  'hard': 0.0003772398616787174,
#  'late': 0.00013472852202811334,
#  'consumptive': 4.490950734270445e-06,
#  'usher': 8.98190146854089e-06,
#  'grammar': 8.98190146854089e-06,
#  'school': 4.490950734270445e-05,
#  'pale': 8.532806395113846e-05,
#  'threadbare': 4.490950734270445e-06,
#  'coat': 0.00012574662055957246,
#  'heart': 0.0004086765168186105,
#  'body': 0.000494004580769749,
#  'brain': 0.00016616517716800647,
#  'i': 0.009520815556653343,
#  'see': 0.0012350114519243723,
#  'ever': 0.0009251358512597117,
#  'dusting': 8.98190146854089e-06,
#  'old': 0.002029909731890241,
#  'lexicons': 4.490950734270445e-06,
#  'grammars': 8.98190146854089e-06,
#  'queer': 0.00019760183230789957,
#  'handkerchief': 2.2454753671352224e-05,
#  'mockingly': 4.490950734270445e-06,
#  'embellished': 1.3472852202811336e-05,
#  'gay': 9.430996541967935e-05,
#  'flags': 4.490950734270445e-06,
#  'known': 0.0003592760587416356,
#  'nations': 5.389140881124534e-05,
#  'world': 0.0007904073292315983,
#  'loved': 1.3472852202811336e-05,
#  'dust': 4.490950734270445e-05,
#  'somehow': 0.00019760183230789957,
#  'mildly': 4.490950734270445e-05,
#  'reminded': 1.796380293708178e-05,
#  'mortality': 4.490950734270445e-06,
#  'while': 0.0011047738806305295,
#  'take': 0.000615260250595051,
#  'others': 0.0001796380293708178,
#  'teach': 2.2454753671352224e-05,
#  'them': 0.002128710648044191,
#  'what': 0.0027709166030448645,
#  'name': 0.00031436655139893113,
#  'be': 0.004773880630529483,
#  'called': 0.0005209502851753717,
#  'our': 0.0009475906049310639,
#  'tongue': 4.940045807697489e-05,
#  'leaving': 0.00017065612790227692,
#  'out': 0.002411640544303229,
#  'through': 0.0010553734225535545,
#  'ignorance': 4.940045807697489e-05,
#  'letter': 7.185521174832712e-05,
#  'h': 1.3472852202811336e-05,
#  'which': 0.0029415727309471417,
#  'alone': 0.0001886199308393587,
#  'maketh': 2.2454753671352224e-05,
#  'signification': 4.490950734270445e-06,
#  'word': 0.0003458032065388243,
#  'deliver': 1.3472852202811336e-05,
#  'that': 0.013836619212287241,
#  'not': 0.005267885211299232,
#  '_hackluyt': 4.490950734270445e-06,
#  '_': 0.0002200565859792518,
#  'sw': 4.490950734270445e-06,
#  'dan': 3.1436655139893116e-05,
#  '_hval_': 4.490950734270445e-06,
#  'animal': 7.185521174832712e-05,
#  'named': 5.389140881124534e-05,
#  'roundness': 4.490950734270445e-06,
#  'rolling': 0.00015718327569946557,
#  '_hvalt_': 4.490950734270445e-06,
#  'arched': 4.940045807697489e-05,
#  'vaulted': 8.98190146854089e-06,
#  '_webster': 4.490950734270445e-06,
#  'dictionary': 1.796380293708178e-05,
#  'more': 0.0022769120222751156,
#  'immediately': 7.634616248259757e-05,
#  'dut': 4.490950734270445e-06,
#  'ger': 4.490950734270445e-06,
#  '_wallen_': 4.490950734270445e-06,
#  '_walw': 4.490950734270445e-06,
#  'ian_': 4.490950734270445e-06,
#  'roll': 8.083711321686801e-05,
#  'wallow': 1.3472852202811336e-05,
#  '_richardson': 4.490950734270445e-06,
#  'חו': 4.490950734270445e-06,
#  '_hebrew_': 4.490950734270445e-06,
#  'ϰητος': 4.490950734270445e-06,
#  '_greek_': 4.490950734270445e-06,
#  'cetus': 1.3472852202811336e-05,
#  '_latin_': 4.490950734270445e-06,
#  'whœl': 4.490950734270445e-06,
#  '_anglo': 4.490950734270445e-06,
#  'saxon_': 4.490950734270445e-06,
#  'hvalt': 4.490950734270445e-06,
#  '_danish_': 4.490950734270445e-06,
#  'wal': 4.490950734270445e-06,
#  '_dutch_': 4.490950734270445e-06,
#  'hwal': 4.490950734270445e-06,
#  '_swedish_': 4.490950734270445e-06,
#  '_icelandic_': 4.490950734270445e-06,
#  '_english_': 4.490950734270445e-06,
#  'ballena': 4.490950734270445e-06,
#  '_spanish_': 4.490950734270445e-06,
#  'pekee': 4.490950734270445e-06,
#  'nuee': 1.796380293708178e-05,
#  '_fegee_': 4.490950734270445e-06,
#  'pehee': 4.490950734270445e-06,
#  '_erromangoan_': 4.490950734270445e-06,
#  'seen': 0.0007410068711546235,
#  'mere': 0.0001886199308393587,
#  'painstaking': 4.490950734270445e-06,
#  'burrower': 4.490950734270445e-06,
#  'grub': 8.98190146854089e-06,
#  'worm': 2.2454753671352224e-05,
#  'poor': 0.0005119683837068308,
#  'devil': 0.0002470022903848745,
#  'appears': 3.592760587416356e-05,
#  'gone': 0.0002649660933219563,
#  'long': 0.0014909956437777878,
#  'vaticans': 4.490950734270445e-06,
#  'stalls': 4.490950734270445e-06,
#  'earth': 0.00020658373377644047,
#  'picking': 1.796380293708178e-05,
#  'whatever': 0.00020658373377644047,
#  'random': 2.2454753671352224e-05,
#  'allusions': 3.1436655139893116e-05,
#  'could': 0.0009745363093366866,
#  'anyways': 8.98190146854089e-06,
#  'find': 0.0002514932411191449,
#  'any': 0.001634706067274442,
#  'book': 0.0002694570440562267,
#  'sacred': 4.490950734270445e-05,
#  'profane': 2.2454753671352224e-05,
#  'therefore': 0.00030089369919611983,
#  'must': 0.0013158485651412403,
#  'every': 0.0010419005703507433,
#  'case': 0.00032334845286747203,
#  'least': 0.00034131225580455384,
#  'higgledy': 4.490950734270445e-06,
#  'piggledy': 4.490950734270445e-06,
#  'statements': 2.2454753671352224e-05,
#  'however': 0.00043113127048996275,
#  'authentic': 1.3472852202811336e-05,
#  'these': 0.0018188350473795302,
#  'veritable': 1.796380293708178e-05,
#  'gospel': 8.98190146854089e-06,
#  'far': 0.0007410068711546235,
#  'touching': 0.00020658373377644047,
#  'ancient': 0.00012574662055957246,
#  'authors': 1.796380293708178e-05,
#  'generally': 0.0001392194727623838,
#  'well': 0.0010329186688822023,
#  'poets': 1.3472852202811336e-05,
#  'here': 0.0014371042349665423,
#  'appearing': 1.796380293708178e-05,
#  'solely': 2.694570440562267e-05,
#  'valuable': 4.940045807697489e-05,
#  'entertaining': 8.98190146854089e-06,
#  'affording': 8.98190146854089e-06,
#  'glancing': 6.287331027978623e-05,
#  'bird': 7.634616248259757e-05,
#  'eye': 0.00039520366461579914,
#  'has': 0.0013158485651412403,
#  'been': 0.0018637445547222348,
#  'promiscuously': 4.490950734270445e-06,
#  'said': 0.0013697399739524857,
#  'thought': 0.0006736426101405668,
#  'fancied': 4.0418556608434004e-05,
#  'sung': 8.98190146854089e-06,
#  'leviathan': 0.0004266403197556923,
#  'many': 0.0007544797233574348,
#  'generations': 3.592760587416356e-05,
#  'including': 7.185521174832712e-05,
#  'own': 0.0009206449005254412,
#  'so': 0.0047873534827322945,
#  'fare': 4.490950734270445e-05,
#  'thee': 0.0005883145461894283,
#  'whose': 0.00039071271388152874,
#  'commentator': 4.490950734270445e-06,
#  'am': 0.00040418556608434004,
#  'thou': 0.0012170476489872905,
#  'belongest': 4.490950734270445e-06,
#  'hopeless': 3.592760587416356e-05,
#  'sallow': 4.490950734270445e-06,
#  'tribe': 4.0418556608434004e-05,
#  'wine': 5.389140881124534e-05,
#  'warm': 0.00010778281762249069,
#  'whom': 0.00020209278304217002,
#  'even': 0.0008667534917141959,
#  'sherry': 4.490950734270445e-06,
#  'would': 0.0019400907172048322,
#  'too': 0.0008308258858400323,
#  'rosy': 8.98190146854089e-06,
#  'strong': 0.00016167422643373602,
#  'but': 0.008187003188575022,
#  'sometimes': 0.00039071271388152874,
#  'loves': 4.490950734270445e-06,
#  'sit': 6.736426101405667e-05,
#  'feel': 0.0002559841918534154,
#  'devilish': 4.0418556608434004e-05,
#  'grow': 0.00010778281762249069,
#  'convivial': 1.796380293708178e-05,
#  'upon': 0.0025508600170656127,
#  'tears': 2.694570440562267e-05,
#  'say': 0.0010957919791619885,
#  'bluntly': 4.490950734270445e-06,
#  'full': 0.0006107692998607806,
#  'eyes': 0.0007005883145461895,
#  'empty': 9.880091615394978e-05,
#  'glasses': 4.490950734270445e-05,
#  'altogether': 0.00013023757129384291,
#  'unpleasant': 1.3472852202811336e-05,
#  'sadness': 8.98190146854089e-06,
#  'subs': 4.490950734270445e-06,
#  'how': 0.001158665289441775,
#  'much': 0.0010059729644765797,
#  'pains': 6.736426101405667e-05,
#  'ye': 0.0021197287465756502,
#  'please': 7.185521174832712e-05,
#  'shall': 0.00043562222122423314,
#  'go': 0.0008667534917141959,
#  'thankless': 4.490950734270445e-06,
#  'clear': 0.00018412898010508824,
#  'hampton': 4.490950734270445e-06,
#  'court': 8.98190146854089e-06,
#  'tuileries': 1.3472852202811336e-05,
#  'gulp': 8.98190146854089e-06,
#  'your': 0.001158665289441775,
#  'hie': 4.490950734270445e-06,
#  'royal': 0.00012574662055957246,
#  'hearts': 0.00013023757129384291,
#  'friends': 7.634616248259757e-05,
#  'who': 0.001643687968742983,
#  'before': 0.001351776171015404,
#  'seven': 7.185521174832712e-05,
#  'storied': 1.796380293708178e-05,
#  'heavens': 7.634616248259757e-05,
#  'making': 0.00020658373377644047,
#  'refugees': 4.490950734270445e-06,
#  'pampered': 4.490950734270445e-06,
#  'gabriel': 8.98190146854089e-05,
#  'michael': 1.3472852202811336e-05,
#  'raphael': 4.490950734270445e-06,
#  'against': 0.0006062783491265101,
#  'coming': 0.00024251133965060402,
#  'strike': 0.00014371042349665424,
#  'splintered': 3.1436655139893116e-05,
#  'together': 0.0002874208469933085,
#  'there': 0.003884672385143935,
#  'unsplinterable': 4.490950734270445e-06,
#  'god': 0.0006871154623433781,
#  'created': 4.0418556608434004e-05,
#  '_genesis_': 4.490950734270445e-06,
#  'path': 4.490950734270445e-05,
#  'shine': 1.3472852202811336e-05,
#  'after': 0.0012125566982530201,
#  'think': 0.0005478959895809943,
#  'deep': 0.00031436655139893113,
#  'hoary': 8.98190146854089e-06,
#  '_job_': 4.490950734270445e-06,
#  'lord': 0.00029191179772757893,
#  'had': 0.0034984506219966766,
#  'prepared': 5.389140881124534e-05,
#  'swallow': 4.940045807697489e-05,
#  '_jonah_': 4.490950734270445e-06,
#  'ships': 0.00039520366461579914,
#  'hast': 0.00013023757129384291,
#  'made': 0.0007993892307001392,
#  'play': 0.00013023757129384291,
#  'therein': 2.694570440562267e-05,
#  '_psalms_': 4.490950734270445e-06,
#  'sore': 1.3472852202811336e-05,
#  'sword': 0.00011227376835676112,
#  'punish': 4.490950734270445e-06,
#  'piercing': 1.796380293708178e-05,
#  'serpent': 1.796380293708178e-05,
#  'crooked': 3.592760587416356e-05,
#  'slay': 1.796380293708178e-05,
#  'dragon': 2.694570440562267e-05,
#  'sea': 0.0020433825840930524,
#  '_isaiah_': 4.490950734270445e-06,
#  'thing': 0.0008442987380428437,
#  'soever': 4.490950734270445e-06,
#  'besides': 0.00022454753671352225,
#  'cometh': 4.490950734270445e-06,
#  'within': 0.00037274891094444694,
#  'chaos': 1.796380293708178e-05,
#  'monster': 0.0002200565859792518,
#  'mouth': 0.00027394799479049713,
#  'beast': 1.796380293708178e-05,
#  'goes': 0.0002470022903848745,
#  'incontinently': 4.490950734270445e-06,
#  'foul': 4.940045807697489e-05,
#  'perisheth': 4.490950734270445e-06,
#  'bottomless': 3.1436655139893116e-05,
#  'gulf': 2.694570440562267e-05,
#  'paunch': 8.98190146854089e-06,
#  '_holland': 8.98190146854089e-06,
#  'plutarch': 4.490950734270445e-06,
#  'morals_': 4.490950734270445e-06,
#  'indian': 0.0002559841918534154,
#  'breedeth': 4.490950734270445e-06,
#  'most': 0.001279920959267077,
#  'biggest': 8.98190146854089e-06,
#  'fishes': 2.2454753671352224e-05,
#  'among': 0.0007499887726231643,
#  'whirlpooles': 4.490950734270445e-06,
#  'balaene': 4.490950734270445e-06,
#  'length': 0.00035029415727309474,
#  'four': 0.00033233035433601294,
#  'acres': 1.3472852202811336e-05,
#  'arpens': 4.490950734270445e-06,
#  'land': 0.0003592760587416356,
#  'pliny_': 4.490950734270445e-06,
#  'scarcely': 4.0418556608434004e-05,
#  'we': 0.002106255894372839,
#  'proceeded': 2.694570440562267e-05,
#  'two': 0.0013293214173440517,
#  'days': 0.0003862217631472583,
#  'on': 0.0048187901378721875,
#  'when': 0.00272600709570216,
#  'about': 0.0014281223334980016,
#  'sunrise': 4.940045807697489e-05,
#  'other': 0.0019311088157362914,
#  'monsters': 4.0418556608434004e-05,
#  'appeared': 4.490950734270445e-05,
#  'former': 8.98190146854089e-05,
#  'size': 5.389140881124534e-05,
#  'came': 0.0005838235954551579,
#  'us': 0.001028427718147932,
#  'open': 0.00034131225580455384,
#  'mouthed': 2.2454753671352224e-05,
#  'raising': 2.2454753671352224e-05,
#  'waves': 0.00021556563524498137,
#  'sides': 0.00012574662055957246,
#  'beating': 4.940045807697489e-05,
#  'into': 0.002348767234023443,
#  'foam': 8.532806395113846e-05,
#  '_tooke': 4.490950734270445e-06,
#  'lucian_': 4.490950734270445e-06,
#  '_the': 5.389140881124534e-05,
#  'history_': 4.490950734270445e-06,
#  'visited': 3.1436655139893116e-05,
#  'country': 0.00012125566982530201,
#  'also': 0.0004176584182871514,
#  'catching': 3.1436655139893116e-05,
#  'horse': 0.00012125566982530201,
#  'bones': 0.0002200565859792518,
#  'very': 0.0014505770871693538,
#  'value': 2.694570440562267e-05,
#  'their': 0.002784389455247676,
#  'brought': 0.00017065612790227692,
#  'some': 0.0027798985045134053,
#  'king': 0.00028292989625903803,
#  'best': 0.0002964027484618494,
#  'were': 0.003067319351506714,
#  'catched': 4.490950734270445e-06,
#  'forty': 0.0001482013742309247,
#  'eight': 0.00012125566982530201,
#  'fifty': 0.0001482013742309247,
#  'yards': 0.00012125566982530201,
#  'six': 0.0001392194727623838,
#  'killed': 0.00015718327569946557,
#  'sixty': 7.634616248259757e-05,
#  '_other': 4.490950734270445e-06,
#  'verbal': 8.98190146854089e-06,
#  'narrative': 4.0418556608434004e-05,
#  'taken': 0.0002290384874477927,
#  'alfred': 8.98190146854089e-06,
#  'd': 0.0003368213050702834,
#  '890': 4.490950734270445e-06,
#  'whereas': 8.083711321686801e-05,
#  'things': 0.0006017873983922397,
#  'whether': 0.0004086765168186105,
#  'vessel': 0.0002470022903848745,
#  'dreadful': 2.694570440562267e-05,
#  'lost': 0.00021107468451071092,
#  'swallowed': 5.838235954551579e-05,
#  'gudgeon': 4.490950734270445e-06,
#  'retires': 4.490950734270445e-06,
#  'security': 1.3472852202811336e-05,
#  'sleeps': 3.1436655139893116e-05,
#  'montaigne': 4.490950734270445e-06,
#  '_apology': 4.490950734270445e-06,
#  'raimond': 4.490950734270445e-06,
#  'sebond_': 4.490950734270445e-06,
#  'let': 0.0007095702160147303,
#  'fly': 6.287331027978623e-05,
#  'nick': 8.98190146854089e-06,
#  'me': 0.00282480801185611,
#  'if': 0.002249966317869493,
#  'described': 4.0418556608434004e-05,
#  'noble': 0.00019760183230789957,
#  'moses': 8.98190146854089e-06,
#  'patient': 2.694570440562267e-05,
#  'job': 6.287331027978623e-05,
#  '_rabelais_': 4.490950734270445e-06,
#  'liver': 1.796380293708178e-05,
#  'cartloads': 4.490950734270445e-06,
#  '_stowe': 4.490950734270445e-06,
#  'annals_': 4.490950734270445e-06,
#  'seas': 0.00039071271388152874,
#  'seethe': 1.3472852202811336e-05,
#  'like': 0.002905645125072978,
#  'boiling': 6.736426101405667e-05,
#  'pan': 2.2454753671352224e-05,
#  '_lord': 4.490950734270445e-06,
#  'bacon': 4.490950734270445e-06,
#  'psalms_': 4.490950734270445e-06,
#  'bulk': 0.00014371042349665424,
#  'ork': 4.490950734270445e-06,
#  'received': 0.0001392194727623838,
#  'nothing': 0.0005164593344411012,
#  'certain': 0.0004086765168186105,
#  'they': 0.002999955090492657,
#  'exceeding': 5.389140881124534e-05,
#  'fat': 6.287331027978623e-05,
#  'insomuch': 8.98190146854089e-06,
#  'an': 0.002694570440562267,
#  'incredible': 4.0418556608434004e-05,
#  'quantity': 5.838235954551579e-05,
#  'oil': 0.00040418556608434004,
#  'extracted': 2.2454753671352224e-05,
#  '_ibid_': 1.3472852202811336e-05,
#  '_history': 4.490950734270445e-06,
#  'death_': 4.490950734270445e-06,
#  'sovereignest': 4.490950734270445e-06,
#  'parmacetti': 1.3472852202811336e-05,
#  'inward': 2.2454753671352224e-05,
#  'bruise': 4.490950734270445e-06,
#  '_king': 4.490950734270445e-06,
#  'henry_': 4.490950734270445e-06,
#  '_hamlet_': 4.490950734270445e-06,
#  'secure': 5.838235954551579e-05,
#  'skill': 4.490950734270445e-05,
#  'leach': 4.490950734270445e-06,
#  'art': 0.00018412898010508824,
#  'mote': 4.490950734270445e-06,
#  'availle': 4.490950734270445e-06,
#  'returne': 4.490950734270445e-06,
#  'againe': 4.490950734270445e-06,
#  'wound': 7.634616248259757e-05,
#  'worker': 4.490950734270445e-06,
#  'lowly': 3.592760587416356e-05,
#  'dinting': 4.490950734270445e-06,
#  'breast': 3.1436655139893116e-05,
#  'bred': 4.0418556608434004e-05,
#  'restless': 1.796380293708178e-05,
#  'paine': 4.490950734270445e-06,
#  'wounded': 4.0418556608434004e-05,
#  'flies': 3.1436655139893116e-05,
#  'thro': 4.490950734270445e-06,
#  'maine': 4.490950734270445e-06,
#  'faerie': 4.490950734270445e-06,
#  'queen_': 4.490950734270445e-06,
#  'immense': 7.185521174832712e-05,
#  'motion': 7.634616248259757e-05,
#  'vast': 0.0003278394036017425,
#  'bodies': 4.0418556608434004e-05,
#  'can': 0.0011092648313648,
#  'peaceful': 2.694570440562267e-05,
#  'calm': 0.00018412898010508824,
#  'trouble': 4.940045807697489e-05,
#  'ocean': 0.00035478510800736514,
#  'till': 0.0005523869403152648,
#  'boil': 8.98190146854089e-06,
#  '_sir': 1.796380293708178e-05,
#  'william': 1.796380293708178e-05,
#  'davenant': 4.490950734270445e-06,
#  'preface': 4.490950734270445e-06,
#  'gondibert_': 4.490950734270445e-06,
#  'spermacetti': 1.3472852202811336e-05,
#  'men': 0.0010957919791619885,
#  'might': 0.0008218439843714915,
#  'justly': 1.3472852202811336e-05,
#  'doubt': 0.00014371042349665424,
#  'since': 0.00029191179772757893,
#  'learned': 0.00011227376835676112,
#  'hosmannus': 4.490950734270445e-06,
#  'work': 0.0004895136300354786,
#  'thirty': 0.00012574662055957246,
#  'years': 0.00043562222122423314,
#  'saith': 2.2454753671352224e-05,
#  'plainly': 0.00017514707863654737,
#  '_nescio': 4.490950734270445e-06,
#  'quid': 8.98190146854089e-06,
#  'sit_': 4.490950734270445e-06,
#  't': 0.0013023757129384291,
#  'browne': 2.694570440562267e-05,
#  'sperma': 1.3472852202811336e-05,
#  'ceti': 1.3472852202811336e-05,
#  'vide': 4.490950734270445e-06,
#  'v': 3.1436655139893116e-05,
#  'e': 0.00023352943818206315,
#  'spencer': 4.490950734270445e-06,
#  'talus': 4.490950734270445e-06,
#  'modern': 8.083711321686801e-05,
#  'flail': 4.490950734270445e-06,
#  'threatens': 4.490950734270445e-06,
#  'ruin': 2.2454753671352224e-05,
#  'ponderous': 5.838235954551579e-05,
#  'fixed': 0.00017065612790227692,
#  'jav': 4.490950734270445e-06,
#  'lins': 4.490950734270445e-06,
#  'side': 0.0009341177527282526,
#  'wears': 3.1436655139893116e-05,
#  'back': 0.0007230430682175417,
#  'grove': 1.3472852202811336e-05,
#  'pikes': 8.98190146854089e-06,
#  '_waller': 4.490950734270445e-06,
#  'battle': 0.0001392194727623838,
#  'summer': 7.185521174832712e-05,
#  'islands_': 4.490950734270445e-06,
#  'commonwealth': 4.490950734270445e-06,
#  'state': 0.0001482013742309247,
#  'latin': 1.796380293708178e-05,
#  'civitas': 4.490950734270445e-06,
#  'artificial': 2.2454753671352224e-05,
#  'man': 0.0023667310369605244,
#  '_opening': 4.490950734270445e-06,
#  'sentence': 1.3472852202811336e-05,
#  'hobbes': 4.490950734270445e-06,
#  'leviathan_': 4.490950734270445e-06,
#  'silly': 2.2454753671352224e-05,
#  'mansoul': 4.490950734270445e-06,
#  'without': 0.000736515920420353,
#  'chewing': 4.490950734270445e-06,
#  'sprat': 4.490950734270445e-06,
#  '_pilgrim': 4.490950734270445e-06,
#  'progress_': 4.490950734270445e-06,
#  'hugest': 1.796380293708178e-05,
#  'swim': 9.430996541967935e-05,
#  'stream': 4.940045807697489e-05,
#  '_paradise': 4.490950734270445e-06,
#  'lost_': 4.490950734270445e-06,
#  'living': 0.0003278394036017425,
#  'creatures': 0.00015269232496519514,
#  'stretched': 4.490950734270445e-05,
#  'promontory': 2.2454753671352224e-05,
#  'swims': 3.592760587416356e-05,
#  'seems': 0.00039071271388152874,
#  'moving': 6.736426101405667e-05,
#  'gills': 1.796380293708178e-05,
#  'draws': 4.490950734270445e-06,
#  'breath': 8.083711321686801e-05,
#  'spouts': 7.185521174832712e-05,
#  'mighty': 0.00021107468451071092,
#  'water': 0.0008532806395113846,
#  'swimming': 0.00013472852202811334,
#  '_fuller': 4.490950734270445e-06,
#  'holy': 9.430996541967935e-05,
#  'state_': 4.490950734270445e-06,
#  'close': 0.0002514932411191449,
#  'behind': 0.00022454753671352225,
#  ...}

# %% [markdown]
# # Finding Similar Words

# %%
def autocorrect(word):
    word = word.lower()
    if word in V:
        return('Your word seems to be correct', word)
    else:
        similarities = [1-(textdistance.Jaccard(qval=2).distance(v,word))  for v in words_freq_dict.keys()]
        df = pd.DataFrame.from_dict(probs, orient='index').reset_index()
        df = df.rename(columns={'index':'Word',0:'Prob'})
        df['Similarity'] = similarities
        output = df.sort_values(['Similarity','Prob'],ascending=False).head(3)
        return(output)
autocorrect("NATURA")
# Out:
#           Word      Prob  Similarity
# 6163   natural  0.000162    0.833333
# 12899    natur  0.000013    0.800000
# 1036    nature  0.000189    0.666667

# %%
autocorrect("th")
# Out:
#      Word      Prob  Similarity
# 0     the  0.066030         0.5
# 4742  thy  0.000503         0.5
# 1153  tho  0.000009         0.5
